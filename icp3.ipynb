# %% [markdown]
# <a href="https://colab.research.google.com/github/buruguchandana27/ICP1/blob/main/icp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the Breast Cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=87)

# Neural network model with additional dense layers
model = Sequential()
model.add(Dense(20, input_dim=X_train.shape[1], activation='relu'))  # Adjusted input_dim for Breast Cancer dataset
model.add(Dense(64, activation='relu'))  # Additional dense layer
model.add(Dense(64, activation='relu'))  # Additional dense layer
model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, Y_train, epochs=100, batch_size=10, verbose=1)

# Model summary
print(model.summary())

# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
print(f'Test Accuracy: {accuracy*100:.2f}%')
# Out:
# Epoch 1/100
# 43/43 [==============================] - 1s 2ms/step - loss: 0.4372 - accuracy: 0.8310
# Epoch 2/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1314 - accuracy: 0.9671
# Epoch 3/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9789
# Epoch 4/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0672 - accuracy: 0.9789
# Epoch 5/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0554 - accuracy: 0.9812
# Epoch 6/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0494 - accuracy: 0.9859
# Epoch 7/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 0.9859
# Epoch 8/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0362 - accuracy: 0.9859
# Epoch 9/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0318 - accuracy: 0.9906
# Epoch 10/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9906
# Epoch 11/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 0.9930
# Epoch 12/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 0.9930
# Epoch 13/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0175 - accuracy: 0.9930
# Epoch 14/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9953
# Epoch 15/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9930
# Epoch 16/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9930
# Epoch 17/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 18/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 19/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 20/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.9977
# Epoch 21/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9977
# Epoch 22/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.9977
# Epoch 23/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 24/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 25/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 26/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 27/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 28/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 29/100
# 43/43 [==============================] - 0s 2ms/step - loss: 9.3241e-04 - accuracy: 1.0000
# Epoch 30/100
# 43/43 [==============================] - 0s 2ms/step - loss: 8.4673e-04 - accuracy: 1.0000
# Epoch 31/100
# 43/43 [==============================] - 0s 3ms/step - loss: 7.3396e-04 - accuracy: 1.0000
# Epoch 32/100
# 43/43 [==============================] - 0s 2ms/step - loss: 6.6886e-04 - accuracy: 1.0000
# Epoch 33/100
# 43/43 [==============================] - 0s 2ms/step - loss: 6.0672e-04 - accuracy: 1.0000
# Epoch 34/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.5466e-04 - accuracy: 1.0000
# Epoch 35/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.3755e-04 - accuracy: 1.0000
# Epoch 36/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.7200e-04 - accuracy: 1.0000
# Epoch 37/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.3569e-04 - accuracy: 1.0000
# Epoch 38/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.2655e-04 - accuracy: 1.0000
# Epoch 39/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.6697e-04 - accuracy: 1.0000
# Epoch 40/100
# 43/43 [==============================] - 0s 3ms/step - loss: 3.5500e-04 - accuracy: 1.0000
# Epoch 41/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.2301e-04 - accuracy: 1.0000
# Epoch 42/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.9993e-04 - accuracy: 1.0000
# Epoch 43/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.7740e-04 - accuracy: 1.0000
# Epoch 44/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.5795e-04 - accuracy: 1.0000
# Epoch 45/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.6192e-04 - accuracy: 1.0000
# Epoch 46/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.3088e-04 - accuracy: 1.0000
# Epoch 47/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.1415e-04 - accuracy: 1.0000
# Epoch 48/100
# 43/43 [==============================] - 0s 3ms/step - loss: 1.9932e-04 - accuracy: 1.0000
# Epoch 49/100
# 43/43 [==============================] - 0s 3ms/step - loss: 1.8873e-04 - accuracy: 1.0000
# Epoch 50/100
# 43/43 [==============================] - 0s 3ms/step - loss: 1.7712e-04 - accuracy: 1.0000
# Epoch 51/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.6742e-04 - accuracy: 1.0000
# Epoch 52/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.6832e-04 - accuracy: 1.0000
# Epoch 53/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.6189e-04 - accuracy: 1.0000
# Epoch 54/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.4962e-04 - accuracy: 1.0000
# Epoch 55/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.3629e-04 - accuracy: 1.0000
# Epoch 56/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.3024e-04 - accuracy: 1.0000
# Epoch 57/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.2756e-04 - accuracy: 1.0000
# Epoch 58/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.1671e-04 - accuracy: 1.0000
# Epoch 59/100
# 43/43 [==============================] - 0s 3ms/step - loss: 1.1140e-04 - accuracy: 1.0000
# Epoch 60/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.0954e-04 - accuracy: 1.0000
# Epoch 61/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.0036e-04 - accuracy: 1.0000
# Epoch 62/100
# 43/43 [==============================] - 0s 3ms/step - loss: 9.7390e-05 - accuracy: 1.0000
# Epoch 63/100
# 43/43 [==============================] - 0s 2ms/step - loss: 9.2686e-05 - accuracy: 1.0000
# Epoch 64/100
# 43/43 [==============================] - 0s 2ms/step - loss: 8.9066e-05 - accuracy: 1.0000
# Epoch 65/100
# 43/43 [==============================] - 0s 2ms/step - loss: 8.6919e-05 - accuracy: 1.0000
# Epoch 66/100
# 43/43 [==============================] - 0s 2ms/step - loss: 8.1502e-05 - accuracy: 1.0000
# Epoch 67/100
# 43/43 [==============================] - 0s 2ms/step - loss: 7.6716e-05 - accuracy: 1.0000
# Epoch 68/100
# 43/43 [==============================] - 0s 5ms/step - loss: 7.4098e-05 - accuracy: 1.0000
# Epoch 69/100
# 43/43 [==============================] - 0s 4ms/step - loss: 7.1267e-05 - accuracy: 1.0000
# Epoch 70/100
# 43/43 [==============================] - 0s 5ms/step - loss: 6.7519e-05 - accuracy: 1.0000
# Epoch 71/100
# 43/43 [==============================] - 0s 3ms/step - loss: 6.4618e-05 - accuracy: 1.0000
# Epoch 72/100
# 43/43 [==============================] - 0s 4ms/step - loss: 6.3182e-05 - accuracy: 1.0000
# Epoch 73/100
# 43/43 [==============================] - 0s 3ms/step - loss: 6.1085e-05 - accuracy: 1.0000
# Epoch 74/100
# 43/43 [==============================] - 0s 4ms/step - loss: 5.9107e-05 - accuracy: 1.0000
# Epoch 75/100
# 43/43 [==============================] - 0s 4ms/step - loss: 5.5177e-05 - accuracy: 1.0000
# Epoch 76/100
# 43/43 [==============================] - 0s 4ms/step - loss: 5.4015e-05 - accuracy: 1.0000
# Epoch 77/100
# 43/43 [==============================] - 0s 4ms/step - loss: 5.1293e-05 - accuracy: 1.0000
# Epoch 78/100
# 43/43 [==============================] - 0s 4ms/step - loss: 4.8935e-05 - accuracy: 1.0000
# Epoch 79/100
# 43/43 [==============================] - 0s 5ms/step - loss: 4.6998e-05 - accuracy: 1.0000
# Epoch 80/100
# 43/43 [==============================] - 0s 4ms/step - loss: 4.5104e-05 - accuracy: 1.0000
# Epoch 81/100
# 43/43 [==============================] - 0s 4ms/step - loss: 4.3354e-05 - accuracy: 1.0000
# Epoch 82/100
# 43/43 [==============================] - 0s 4ms/step - loss: 4.2531e-05 - accuracy: 1.0000
# Epoch 83/100
# 43/43 [==============================] - 0s 4ms/step - loss: 4.0084e-05 - accuracy: 1.0000
# Epoch 84/100
# 43/43 [==============================] - 0s 5ms/step - loss: 3.8339e-05 - accuracy: 1.0000
# Epoch 85/100
# 43/43 [==============================] - 0s 6ms/step - loss: 3.7147e-05 - accuracy: 1.0000
# Epoch 86/100
# 43/43 [==============================] - 0s 4ms/step - loss: 3.5707e-05 - accuracy: 1.0000
# Epoch 87/100
# 43/43 [==============================] - 0s 5ms/step - loss: 3.4513e-05 - accuracy: 1.0000
# Epoch 88/100
# 43/43 [==============================] - 0s 3ms/step - loss: 3.3423e-05 - accuracy: 1.0000
# Epoch 89/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.2635e-05 - accuracy: 1.0000
# Epoch 90/100
# 43/43 [==============================] - 0s 3ms/step - loss: 3.1423e-05 - accuracy: 1.0000
# Epoch 91/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.0034e-05 - accuracy: 1.0000
# Epoch 92/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.8876e-05 - accuracy: 1.0000
# Epoch 93/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.8220e-05 - accuracy: 1.0000
# Epoch 94/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.7314e-05 - accuracy: 1.0000
# Epoch 95/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.5899e-05 - accuracy: 1.0000
# Epoch 96/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.5565e-05 - accuracy: 1.0000
# Epoch 97/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.5181e-05 - accuracy: 1.0000
# Epoch 98/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.3511e-05 - accuracy: 1.0000
# Epoch 99/100
# 43/43 [==============================] - 0s 3ms/step - loss: 2.2704e-05 - accuracy: 1.0000
# Epoch 100/100
# 43/43 [==============================] - 0s 3ms/step - loss: 2.2181e-05 - accuracy: 1.0000
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 20)                620
#
#  dense_14 (Dense)            (None, 64)                1344
#
#  dense_15 (Dense)            (None, 64)                4160
#
#  dense_16 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 6189 (24.18 KB)
# Trainable params: 6189 (24.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Test Accuracy: 97.20%

# %%
from keras.datasets import mnist
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Preprocess the data
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0], dimData).astype('float32') / 255
test_data = test_images.reshape(test_images.shape[0], dimData).astype('float32') / 255
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# Creating the network
model = Sequential([
    Dense(512, activation='relu', input_shape=(dimData,)),
    Dense(512, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                    validation_data=(test_data, test_labels_one_hot))

# Plotting the accuracy and loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()
plt.show()

# Predicting a single image
def predict_single_image(image_data):
    image_data = image_data.reshape(1, dimData).astype('float32') / 255
    prediction = model.predict(image_data)
    predicted_class = np.argmax(prediction)
    return predicted_class

# Choose an image from the test set
image_index = 0  # Change this to see different predictions
predicted_class = predict_single_image(test_images[image_index])
print(f'Predicted class for image at index {image_index}: {predicted_class}')
plt.imshow(test_images[image_index], cmap='gray')
plt.title(f'Image at index {image_index} - Predicted as: {predicted_class}')
plt.show()

# Modify the model to use different activation functions and fewer layers for comparison
# You can adjust the following model architecture as needed
model_tanh = Sequential([
    Dense(512, activation='tanh', input_shape=(dimData,)),
    Dense(10, activation='softmax')
])

model_tanh.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model_tanh.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
               validation_data=(test_data, test_labels_one_hot))

# To compare performance without scaling, you would need to adjust the data preprocessing
# and re-train the model. This is not included here for brevity but can be done by removing
# the division by 255 in the data preprocessing steps.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 235/235 [==============================] - 12s 40ms/step - loss: 0.2866 - accuracy: 0.9121 - val_loss: 0.1455 - val_accuracy: 0.9548
# Epoch 2/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.1022 - accuracy: 0.9688 - val_loss: 0.0841 - val_accuracy: 0.9743
# Epoch 3/10
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0638 - accuracy: 0.9804 - val_loss: 0.0955 - val_accuracy: 0.9705
# Epoch 4/10
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0437 - accuracy: 0.9865 - val_loss: 0.0950 - val_accuracy: 0.9720
# Epoch 5/10
# 235/235 [==============================] - 5s 22ms/step - loss: 0.0317 - accuracy: 0.9901 - val_loss: 0.0669 - val_accuracy: 0.9790
# Epoch 6/10
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0238 - accuracy: 0.9923 - val_loss: 0.0553 - val_accuracy: 0.9843
# Epoch 7/10
# 235/235 [==============================] - 5s 23ms/step - loss: 0.0170 - accuracy: 0.9947 - val_loss: 0.0653 - val_accuracy: 0.9817
# Epoch 8/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 0.0904 - val_accuracy: 0.9749
# Epoch 9/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.0850 - val_accuracy: 0.9791
# Epoch 10/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.0628 - val_accuracy: 0.9855
# 1/1 [==============================] - 0s 140ms/step
# Predicted class for image at index 0: 7
# Epoch 1/10
# 235/235 [==============================] - 5s 18ms/step - loss: 0.3949 - accuracy: 0.8846 - val_loss: 0.2898 - val_accuracy: 0.9121
# Epoch 2/10
# 235/235 [==============================] - 3s 14ms/step - loss: 0.2329 - accuracy: 0.9321 - val_loss: 0.2298 - val_accuracy: 0.9281
# Epoch 3/10
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1692 - accuracy: 0.9511 - val_loss: 0.1759 - val_accuracy: 0.9492
# Epoch 4/10
# 235/235 [==============================] - 5s 21ms/step - loss: 0.1292 - accuracy: 0.9623 - val_loss: 0.1256 - val_accuracy: 0.9622
# Epoch 5/10
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1027 - accuracy: 0.9710 - val_loss: 0.1030 - val_accuracy: 0.9692
# Epoch 6/10
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0844 - accuracy: 0.9756 - val_loss: 0.1020 - val_accuracy: 0.9684
# Epoch 7/10
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0694 - accuracy: 0.9797 - val_loss: 0.0913 - val_accuracy: 0.9727
# Epoch 8/10
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0582 - accuracy: 0.9828 - val_loss: 0.0752 - val_accuracy: 0.9761
# Epoch 9/10
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0489 - accuracy: 0.9859 - val_loss: 0.0799 - val_accuracy: 0.9749
# Epoch 10/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0410 - accuracy: 0.9884 - val_loss: 0.0762 - val_accuracy: 0.9771
